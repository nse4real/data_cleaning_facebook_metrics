# %% [markdown]
# <a href="https://colab.research.google.com/github/nse4real/data_cleaning_facebook_metrics/blob/main/data_cleaning_mising_values_tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Install needed library
# !install data-cleaning
# # IMPORT NEEDED LIBRARIES
# import DataCleaning
# import pandas as pd
# import numpy as np

# %%
import pandas as pd
import numpy as np
! pip install data-cleaning
from datacleaning import DataCleaning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# read in all our data, also convert txt to csv
tweets = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/dataset.csv")

# %%
# set seed for reproducibility
np.random.seed(0)

# %%
# look at a few rows of the hepc file. I can see a handful of missing data already!
tweets.sample(5)
# Out:
#                                      input.access_token     input.exclude  \
# 3959  AAAAAAAAAAAAAAAAAAAAAAyUYgEAAAAAYT3ZR%2Bw6cIB8...  retweets,replies
# 1457  AAAAAAAAAAAAAAAAAAAAAAyUYgEAAAAAYT3ZR%2Bw6cIB8...  retweets,replies
# 4256  AAAAAAAAAAAAAAAAAAAAAAyUYgEAAAAAYT3ZR%2Bw6cIB8...  retweets,replies
# 308   AAAAAAAAAAAAAAAAAAAAAAyUYgEAAAAAYT3ZR%2Bw6cIB8...  retweets,replies
# 2383  AAAAAAAAAAAAAAAAAAAAAAyUYgEAAAAAYT3ZR%2Bw6cIB8...  retweets,replies
#
#                          input.tweet_fields  input.user_id  \
# 3959  public_metrics,created_at,text,source       18903971
# 1457  public_metrics,created_at,text,source        5520952
# 4256  public_metrics,created_at,text,source       18903971
# 308   public_metrics,created_at,text,source       27699224
# 2383  public_metrics,created_at,text,source      426044697
#
#                              input.pagination_token  \
# 3959  7140dibdnow9c7btw3z2gqxbo3lt80q1nijtlddk07i2a
# 1457  7140dibdnow9c7btw3n4mh9e880bjujcdjmfwx3x0c3so
# ...

# %%
# get the number of missing data points per column
missing_values_count = tweets.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:19]
# Out:
# input.access_token                     0
# input.exclude                          0
# input.tweet_fields                     0
# input.user_id                          0
# input.pagination_token               600
# data.public_metrics.retweet_count      0
# data.public_metrics.reply_count        0
# data.public_metrics.like_count         0
# data.public_metrics.quote_count        0
# data.source                            0
# data.text                              0
# data.id                                0
# data.created_at                        0
# meta.oldest_id                         0
# meta.newest_id                         0
# meta.result_count                      0
# meta.next_token                      260
# meta.previous_token                  600
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(tweets.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 1.7787524366471734

# %%
twt = DataCleaning(file_upload='/content/drive/MyDrive/Colab Notebooks/dataset.csv')
cleaned_twt = twt.start_cleaning()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/missingpy/missforest.py:528: UserWarning: No missing value located; returning original dataset.
#   warnings.warn("No missing value located; returning original "

# %%
# remove all the rows that contain a missing value
cleaned_twt.dropna()
# Out:
#       input.user_id  data.public_metrics.retweet_count  \
# 0        27699224.0                                0.0
# 1        27699224.0                                2.0
# 2        27699224.0                                7.0
# 3        27699224.0                                0.0
# 4        27699224.0                                0.0
# ...             ...                                ...
# 4555     18903971.0                                2.0
# 4556     18903971.0                                1.0
# 4557     18903971.0                                8.0
# 4558     18903971.0                                7.0
# 4559     18903971.0                                5.0
#
#       data.public_metrics.reply_count  data.public_metrics.like_count  \
# 0                                 1.0                            15.0
# 1                                 4.0                            66.0
# 2                                 3.0                            67.0
# ...
